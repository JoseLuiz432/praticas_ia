# %% [markdown]
# # Python fundamentos
#
# Neste notebook vamos cobrir os fundamentos de python.
#
# ## Conteúdo
#
# 1. Comentários
# 2. Tipos de dados
# 3. Operadores aritméticos e relacionados
# 4. Estruturas condicionais
# 5. Operadores lógicos
# 6. Laços de repetição (for e while)
# 7. Controle de fluxo com 'break' e 'continue'
# 8. Iteração sobre listas e strings
# 9. Definições e chamadas de função
# 10. Funções lambda
# 11. Escopo de variáveis
# 12. Estrutura de dados
# 13. Operações básicas com lista
# 14. Operações básicas com dicionário
# 15. Compreensão de lista
# 16. Tratamento de exceções

# %% [markdown]
# ## Comentários
